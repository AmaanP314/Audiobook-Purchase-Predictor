# %% [markdown]
# ## Importing relevant libraries

# %%
import numpy as np
from sklearn import preprocessing
import tensorflow as tf
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# %%
path = r"Audiobooks_data.csv"
raw_data = np.loadtxt(path, delimiter=',')
raw_data.shape
# Out:
# (14084, 12)

# %% [markdown]
# # Preprocessing

# %%
unscaled_inputs = raw_data[:, 1:-1]
targets = raw_data[:, -1]
unscaled_inputs
# Out:
# array([[2.160e+03, 2.160e+03, 1.013e+01, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [1.404e+03, 2.808e+03, 6.660e+00, ..., 0.000e+00, 0.000e+00,
#         1.820e+02],
#        [3.240e+02, 3.240e+02, 1.013e+01, ..., 0.000e+00, 1.000e+00,
#         3.340e+02],
#        ...,
#        [1.080e+03, 1.080e+03, 6.550e+00, ..., 0.000e+00, 0.000e+00,
#         2.900e+01],
#        [2.160e+03, 2.160e+03, 6.140e+00, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [1.620e+03, 1.620e+03, 5.330e+00, ..., 0.000e+00, 0.000e+00,
#         9.000e+01]])

# %%
tot_ones = int(targets.sum())
tot_ones
# Out:
# 2237

# %%
zero_count = 0
indices_remove = []
for i in range(len(targets)):
    if targets[i] == 0:
        zero_count += 1
        if zero_count > tot_ones:
            indices_remove.append(i)

# %%
balanced_input = np.delete(unscaled_inputs, indices_remove, 0)
targets = np.delete(targets, indices_remove, 0)

# %%
inputs = preprocessing.scale(balanced_input)

# %%
shuffle_indices = np.arange(len(inputs))
np.random.shuffle(shuffle_indices)
inputs = inputs[shuffle_indices]
targets = targets[shuffle_indices]

# %%
count = len(inputs)
train_count = int(0.8 * count)
valid_count = int(0.1 * count)
test_count = count - train_count - valid_count

# %%
train_inputs = inputs[:train_count]
train_targets = targets[:train_count]

valid_inputs = inputs[train_count : train_count + valid_count]
valid_targets = targets[train_count : train_count + valid_count]

test_inputs = inputs[train_count + valid_count : ]
test_targets = targets[train_count + valid_count : ]

# %%
np.savez('Audiobooks_data_train', inputs=train_inputs, targets=train_targets)
np.savez('Audiobooks_data_validation', inputs=valid_inputs, targets=valid_targets)
np.savez('Audiobooks_data_test', inputs=test_inputs, targets=test_targets)

# %%
npz = np.load('Audiobooks_data_train.npz')

train_inputs = npz['inputs'].astype(float)
train_targets = npz['targets'].astype(int)

npz = np.load('Audiobooks_data_validation.npz')
validation_inputs, validation_targets = npz['inputs'].astype(float), npz['targets'].astype(int)

npz = np.load('Audiobooks_data_test.npz')
test_inputs, test_targets = npz['inputs'].astype(float), npz['targets'].astype(int)

# %% [markdown]
# # Building model

# %%
input_size = 10
output_size = 2
hidden_size = 200

model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_size, activation= 'relu'),
    tf.keras.layers.Dense(hidden_size, activation= 'tanh'),
    tf.keras.layers.Dense(hidden_size, activation= 'relu'),
    tf.keras.layers.Dense(output_size, activation= 'softmax'),
])

model.compile(optimizer='adam', loss = 'sparse_categorical_crossentropy', metrics= ['accuracy'])

# %%
early_stop = tf.keras.callbacks.EarlyStopping(patience = 2, restore_best_weights=True)
model.fit(train_inputs,
          train_targets,
          batch_size=100,
          epochs=100,
          validation_data=(validation_inputs, validation_targets),
          callbacks=[early_stop],
          verbose=2)
# Out:
# Epoch 1/100
# 36/36 - 3s - 70ms/step - accuracy: 0.8642 - loss: 0.3654 - val_accuracy: 0.9016 - val_loss: 0.2661
# Epoch 2/100
# 36/36 - 0s - 13ms/step - accuracy: 0.8969 - loss: 0.2760 - val_accuracy: 0.9128 - val_loss: 0.2421
# Epoch 3/100
# 36/36 - 0s - 7ms/step - accuracy: 0.8908 - loss: 0.2694 - val_accuracy: 0.9060 - val_loss: 0.2667
# Epoch 4/100
# 36/36 - 0s - 10ms/step - accuracy: 0.9008 - loss: 0.2538 - val_accuracy: 0.9083 - val_loss: 0.2375
# Epoch 5/100
# 36/36 - 0s - 8ms/step - accuracy: 0.9058 - loss: 0.2506 - val_accuracy: 0.9150 - val_loss: 0.2356
# Epoch 6/100
# 36/36 - 0s - 7ms/step - accuracy: 0.9098 - loss: 0.2443 - val_accuracy: 0.9172 - val_loss: 0.2443
# Epoch 7/100
# 36/36 - 0s - 7ms/step - accuracy: 0.9058 - loss: 0.2456 - val_accuracy: 0.9172 - val_loss: 0.2479

# %% [markdown]
# ## Saving & Testing the Model

# %%
model.save('audiobook_prediction_model.keras')

# %%
load_model = tf.keras.models.load_model('audiobook_prediction_model.keras')
predictions = load_model.predict(test_inputs)
predicted_classes = np.argmax(predictions, axis=1)

for i, (prediction, actual) in enumerate(zip(predicted_classes, test_targets)):
    status_prediction = "Will Buy Again!" if prediction == 1 else "Wont't Buy Again"
    status_actual = "Will Buy Again!!" if actual == 1 else "Won't Buy Again"
 
    if prediction == actual:
        result = "Correct!"
    else:
        result = "Wrong"
 
    print(f"Customer {i+1}: Prediction = {status_prediction}, Actual = {status_actual} -> {result}")
print('\n')
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
print('\nTest loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Customer 1: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 2: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 3: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 4: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 5: Prediction = Will Buy Again!, Actual = Won't Buy Again -> Wrong
# Customer 6: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 7: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 8: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 9: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 10: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 11: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 12: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 13: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 14: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 15: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 16: Prediction = Will Buy Again!, Actual = Won't Buy Again -> Wrong
# Customer 17: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 18: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 19: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 20: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 21: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 22: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 23: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 24: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 25: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 26: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 27: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 28: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 29: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 30: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 31: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 32: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 33: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 34: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 35: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 36: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 37: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 38: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 39: Prediction = Will Buy Again!, Actual = Won't Buy Again -> Wrong
# Customer 40: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 41: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 42: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 43: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 44: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 45: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 46: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 47: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 48: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 49: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 50: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 51: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 52: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 53: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 54: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 55: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 56: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 57: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 58: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 59: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 60: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 61: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 62: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 63: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 64: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 65: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 66: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 67: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 68: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 69: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 70: Prediction = Will Buy Again!, Actual = Won't Buy Again -> Wrong
# Customer 71: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 72: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 73: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 74: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 75: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 76: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 77: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 78: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 79: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 80: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 81: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 82: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 83: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 84: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 85: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 86: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 87: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 88: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 89: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 90: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 91: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 92: Prediction = Will Buy Again!, Actual = Won't Buy Again -> Wrong
# Customer 93: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 94: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 95: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 96: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 97: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 98: Prediction = Will Buy Again!, Actual = Won't Buy Again -> Wrong
# Customer 99: Prediction = Will Buy Again!, Actual = Won't Buy Again -> Wrong
# Customer 100: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 101: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 102: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 103: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 104: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 105: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 106: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 107: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 108: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 109: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 110: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 111: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 112: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 113: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 114: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 115: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 116: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 117: Prediction = Wont't Buy Again, Actual = Will Buy Again!! -> Wrong
# Customer 118: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 119: Prediction = Will Buy Again!, Actual = Won't Buy Again -> Wrong
# Customer 120: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 121: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 122: Prediction = Will Buy Again!, Actual = Won't Buy Again -> Wrong
# Customer 123: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 124: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 125: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 126: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 127: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 128: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 129: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 130: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 131: Prediction = Will Buy Again!, Actual = Will Buy Again!! -> Correct!
# Customer 132: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer 133: Prediction = Wont't Buy Again, Actual = Won't Buy Again -> Correct!
# Customer